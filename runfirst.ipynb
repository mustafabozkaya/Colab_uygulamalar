# %%
#https://medium.com/deep-learning-turkiye/google-colab-ile-%C3%BCcretsiz-gpu-kullan%C4%B1m%C4%B1-30fdb7dd822e

# %%
def quicksort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quicksort(left) + middle + quicksort(right)

print(quicksort([3,6,8,10,1,2,1]))
# Out:
# [1, 1, 2, 3, 6, 8, 10]

# %%
# !python rakam_tanima_CNN_MNIST.py
# Out:
# python3: can't open file 'rakam_tanima_CNN_MNIST.py': [Errno 2] No such file or directory

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 160706 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.26-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.26-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.26-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# ...

# %%
# !mkdir -p drivess
# !google-drive-ocamlfuse drivess

# %%
import sys
sys.path.insert(0, '/chapter1')

# %%
# !ls
# Out:
# adc.json  drive  drivess  pratik-derin-ogrenme-uygulamalari  sample_data

# %%
ls drive/MyDrive/Colab\ Notebooks/colab_uygulamalar
# Out:
# drive_colab_git_commands.ipynb  rakam_tanima_CNN_MNIST.py  runfirst.ipynb

# %%
# !pip install -q  keras

# %%
# !python3 drive/MyDrive/Colab\ Notebooks/colab_uygulamalar/rakam_tanima_CNN_MNIST.py
# Out:
# 2021-05-27 11:31:25.111210: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...
# 11501568/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Traceback (most recent call last):
#   File "drive/MyDrive/Colab Notebooks/colab_uygulamalar/rakam_tanima_CNN_MNIST.py", line 61, in <module>
#     y_train = keras.utils.to_categorical(y_train, num_classes)
# AttributeError: module 'keras.utils' has no attribute 'to_categorical'

# %%
ls
# Out:
# MyDrive/

# %%
cd MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/mustafabozkaya/pratik-derin-ogrenme-uygulamalari.git
# Out:
# Cloning into 'pratik-derin-ogrenme-uygulamalari'...
# remote: Enumerating objects: 268, done.
# remote: Total 268 (delta 0), reused 0 (delta 0), pack-reused 268
# Receiving objects: 100% (268/268), 13.28 MiB | 14.47 MiB/s, done.
# Resolving deltas: 100% (83/83), done.

# %%
 ls
# Out:
#  chapter1/           pratik-derin-ogrenme-uygulamalari/
# 'Colab Notebooks'/  'Untitled Diagram.drawio'

# %%
ls drive/Colab\ Notebooks/colab_uygulamalar
# Out:
# ls: cannot access 'drive/Colab Notebooks/colab_uygulamalar': No such file or directory

# %%
ls pratik-derin-ogrenme-uygulamalari/
# Out:
# images/  KERAS/  NasılKatkıdaBulunabilrim.md  PyTorch/  README.md

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cd pratik-derin-ogrenme-uygulamalari/

# %%
# %ldir
# Out:
# drwx------ 5 root 4096 May 21 11:25 drive/
# drwxr-xr-x 2 root 4096 May 21 11:24 drives/
# drwxr-xr-x 6 root 4096 May 21 11:27 pratik-derin-ogrenme-uygulamalari/
# drwxr-xr-x 1 root 4096 May  6 13:44 sample_data/

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# ''

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 12740968868013098701]

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13305332 kB
# MemFree:        10344320 kB
# MemAvailable:   12362308 kB
# Buffers:           95268 kB
# Cached:          2046952 kB
# SwapCached:            0 kB
# Active:          1129776 kB
# Inactive:        1586528 kB
# Active(anon):     528636 kB
# Inactive(anon):      436 kB
# Active(file):     601140 kB
# Inactive(file):  1586092 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               352 kB
# Writeback:             0 kB
# AnonPages:        574096 kB
# Mapped:           395448 kB
# Shmem:              1168 kB
# KReclaimable:     144456 kB
# Slab:             190180 kB
# SReclaimable:     144456 kB
# SUnreclaim:        45724 kB
# KernelStack:        5008 kB
# PageTables:         7652 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6652664 kB
# Committed_AS:    3700812 kB
# VmallocTotal:   34359738367 kB
# ...
